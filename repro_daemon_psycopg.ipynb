# %%
# %pip install 'pixeltable[serve]==0.7.3'

# %%
# %%writefile repro_daemon_psycopg.py
import pixeltable as pxt

TableModel = pxt.model_base()


class Items(TableModel, name='items'):
    title: pxt.String
    note: pxt.String | None
# Out:
# Overwriting repro_daemon_psycopg.py

# %%
# !pxt init
# Out:
# project root: /Users/alison-pxt/Documents/Github/pxt-champs
# already configured by pyproject.toml

# %%
# !pxt schema update repro_daemon_psycopg.py demo
# Out:
# pxt: 500 ImportError: the psycopg package should be imported before psycopg_binary
#
# --- daemon traceback ---
# Traceback (most recent call last):
#   File "/Users/alison-pxt/Documents/Github/pxt-champs/.venv/lib/python3.12/site-packages/pixeltable_cli/server/http_server.py", line 126, in _dispatch
#     result = handler(req)
#              ^^^^^^^^^^^^
#   File "/Users/alison-pxt/Documents/Github/pxt-champs/.venv/lib/python3.12/site-packages/pixeltable_cli/server/routes.py", line 508, in schema_diff
#     return _SCHEMA_PLAN.validate_python(bridge.schema_diff(body.schema_file, req.resolve_path(body.catalog_dir)))
#                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/alison-pxt/Documents/Github/pxt-champs/.venv/lib/python3.12/site-packages/pixeltable_cli/server/bridge.py", line 726, in schema_diff
#     return _schema_plan(model_bases, schema_file, catalog_dir)
# ...
