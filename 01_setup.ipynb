# %% [markdown]
# # Setup
#
# Install Pixeltable and connect to your Cloud account. About 5 minutes.

# %%
# !uv sync

# %% [markdown]
# Put your Cloud API key (dashboard → API Keys, shown once) in `~/.pixeltable/config.toml`:
#
# ```toml
# [pixeltable]
# api_key = 'your-api-key'
# ```
#
# Then restart the kernel and confirm it is set and find your org slug:

# %%
# !pxt config     # pixeltable.api_key shows <redacted>
# !pxt org list   # your org slug

# %% [markdown]
# Next: `02_cloud_tables.ipynb`.
